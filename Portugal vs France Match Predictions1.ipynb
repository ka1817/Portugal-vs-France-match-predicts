# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Create the dataset
data = {
    "Match Date": ["1996-01-24", "2000-06-28", "2001-04-25", "2006-07-05", "2014-10-11", "2015-09-04", "2016-07-10", "2020-11-14", "2021-06-23"],
    "Competition": ["Friendly", "Euro 2000 Semi-Final", "Friendly", "World Cup Semi-Final", "Friendly", "Friendly", "Euro 2016 Final", "UEFA Nations League", "Euro 2020 Group Stage"],
    "Venue": ["Neutral", "Neutral", "Home", "Neutral", "Home", "Away", "Neutral", "Home", "Neutral"],
    "Final Score": ["2-3", "1-2 (AET)", "4-2", "0-1", "1-0 (AET)", "1-2", "0-1", "0-1", "2-2"],
    "Outcome": ["Loss", "Loss", "Win", "Loss", "Win", "Loss", "Win", "Loss", "Draw"],
    "Portugal Goals": [2, 1, 4, 0, 1, 0, 1, 0, 2],
    "France Goals": [3, 2, 2, 1, 0, 1, 0, 1, 2],
    "Portugal FIFA Rank": [10, 10, 9, 7, 11, 7, 8, 5, 5],
    "France FIFA Rank": [4, 1, 2, 4, 10, 24, 17, 2, 2],
    "Portugal Recent Form": ["W-D-L-D-W", "W-W-W-W-D", "W-D-L-D-W", "W-W-W-W-L", "W-W-W-D-L", "W-L-W-W-W", "W-W-W-D-W", "W-W-D-W-W", "W-D-W-W-D"],
    "France Recent Form": ["W-W-W-D-W", "W-W-W-W-D", "W-W-W-D-W", "W-W-W-W-D", "W-W-W-D-W", "W-W-D-D-W", "W-W-W-W-W", "W-W-D-W-D", "W-W-W-D-W"],
    "Portugal Top Scorer": ["João Pinto", "Nuno Gomes", "Luís Figo", "Pauleta", "Ronaldo", "Ronaldo", "Ronaldo", "Ronaldo", "Ronaldo"],
    "France Top Scorer": ["Youri Djorkaeff", "Zinedine Zidane", "Thierry Henry", "Zinedine Zidane", "Karim Benzema", "Mathieu Valbuena", "Antoine Griezmann", "N'Golo Kante", "Karim Benzema"],
    "Match Importance": ["Friendly", "Semi-Final", "Friendly", "Semi-Final", "Friendly", "Friendly", "Final", "Group Stage", "Group Stage"],
    "Weather": ["Clear", "Clear", "Clear", "Clear", "Clear", "Clear", "Clear", "Clear", "Clear"],
    "Crowd Support": ["Neutral", "Neutral", "Home", "Neutral", "Home", "Away", "Neutral", "Home", "Neutral"],
    "Injuries/Suspensions": ["N/A", "N/A", "N/A", "Deco (Suspended)", "Pepe (Injured)", "N/A", "N/A", "N/A", "N/A"],
    "Coach Portugal": ["António Oliveira", "Humberto Coelho", "António Oliveira", "Luiz Felipe Scolari", "Fernando Santos", "Fernando Santos", "Fernando Santos", "Fernando Santos", "Fernando Santos"],
    "Coach France": ["Aimé Jacquet", "Roger Lemerre", "Roger Lemerre", "Raymond Domenech", "Didier Deschamps", "Didier Deschamps", "Didier Deschamps", "Didier Deschamps", "Didier Deschamps"],
    "Possession Portugal": [48, 47, 51, 44, 51, 46, 44, 49, 46],
    "Possession France": [52, 53, 49, 56, 49, 54, 56, 51, 54],
    "Shots on Target Portugal": [5, 5, 7, 3, 4, 3, 3, 4, 5],
    "Shots on Target France": [6, 6, 5, 5, 7, 5, 6, 4, 6],
    "Corner Kicks Portugal": [3, 3, 5, 4, 2, 2, 2, 3, 4],
    "Corner Kicks France": [5, 5, 4, 6, 4, 5, 8, 3, 5],
    "Yellow Cards Portugal": [2, 2, 1, 2, 1, 1, 3, 2, 2],
    "Yellow Cards France": [1, 1, 2, 1, 1, 0, 3, 2, 1],
    "Red Cards Portugal": [0, 0, 0, 0, 0, 0, 0, 0, 0],
    "Red Cards France":[0, 0, 0, 0, 0, 0, 0, 0,0]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    Match Date            Competition    Venue Final Score Outcome  \
# 0  1996-01-24               Friendly  Neutral         2-3    Loss
# 1  2000-06-28   Euro 2000 Semi-Final  Neutral   1-2 (AET)    Loss
# 2  2001-04-25               Friendly     Home         4-2     Win
# 3  2006-07-05   World Cup Semi-Final  Neutral         0-1    Loss
# 4  2014-10-11               Friendly     Home   1-0 (AET)     Win
# 5  2015-09-04               Friendly     Away         1-2    Loss
# 6  2016-07-10        Euro 2016 Final  Neutral         0-1     Win
# 7  2020-11-14    UEFA Nations League     Home         0-1    Loss
# 8  2021-06-23  Euro 2020 Group Stage  Neutral         2-2    Draw
#
#    Portugal Goals  France Goals  Portugal FIFA Rank  France FIFA Rank  \
# 0               2             3                  10                 4
# 1               1             2                  10                 1
# 2               4             2                   9                 2
# ...

# %%
df['Outcome Binary'] = df['Outcome'].map({'Win': 1, 'Loss': 0, 'Draw': 0})
df['VenueB']=df['Venue'].map({'Home':1,'Away':0,'Neutral':0})

# Define mapping for 'Match Importance' and handle cases where values are not mapped
df['Match ImportanceB'] = df['Match Importance'].map({'Final': 1, 'Semi-Final': 1, 'Friendly': 0, 'Group Stage': 0})

# Check if there are any NaN values resulting from mapping
print(df['Match ImportanceB'].isna().sum())

# Fill NaN values with a default value (e.g., 0) if needed
df['Match ImportanceB'] = df['Match ImportanceB'].fillna(0).astype(int)



df['Crowd SupportB']=df['Crowd Support'].map({'Home':1,'Away':0,'Neutral':0})
# Out:
# 0

# %%
df
# Out:
#    Match Date            Competition    Venue Final Score Outcome  \
# 0  1996-01-24               Friendly  Neutral         2-3    Loss
# 1  2000-06-28   Euro 2000 Semi-Final  Neutral   1-2 (AET)    Loss
# 2  2001-04-25               Friendly     Home         4-2     Win
# 3  2006-07-05   World Cup Semi-Final  Neutral         0-1    Loss
# 4  2014-10-11               Friendly     Home   1-0 (AET)     Win
# 5  2015-09-04               Friendly     Away         1-2    Loss
# 6  2016-07-10        Euro 2016 Final  Neutral         0-1     Win
# 7  2020-11-14    UEFA Nations League     Home         0-1    Loss
# 8  2021-06-23  Euro 2020 Group Stage  Neutral         2-2    Draw
#
#    Portugal Goals  France Goals  Portugal FIFA Rank  France FIFA Rank  \
# 0               2             3                  10                 4
# 1               1             2                  10                 1
# 2               4             2                   9                 2
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#1)LOGISTIC REGRESSION
#With High Test size which is generally insufficient for effectively training a machine learning model.
#Achieving high accuracy with a dataset of only 9 rows and 29 columns is very challenging due to the inherent limitations of small datasets. 
#Here’s a summary of why achieving more than 70% accuracy might be difficult and some strategies to address these challenges:

# %%
#LOGISTIC REGRESSION
# Define feature columns and target variable
X = df[['Portugal Goals','France Goals','Portugal FIFA Rank','France FIFA Rank','VenueB','Match ImportanceB','Crowd SupportB']]
y = df['Outcome Binary']

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y,random_state=42)


# Feature scaling (optional but recommended for logistic regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create and train the logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Make predictions
y_pred = model.predict(X_test_scaled)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# %%
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3333333333333333

# %%
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[1 1]
#  [1 0]]

# %%
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.33         3
#    macro avg       0.25      0.25      0.25         3
# weighted avg       0.33      0.33      0.33         3

# %%
#With very small Dataset achieving good performance and reliable results with machine learning models is challenging. Here are strategies to improve model performance 
#Leave-One-Out Cross-Validation (LOOCV)
from sklearn.model_selection import LeaveOneOut

# %%
model = LogisticRegression(max_iter=1000)
loo = LeaveOneOut()

y_pred2 = []
y_true = []

for train_index, test_index in loo.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    model.fit(X_train, y_train)
    y_pred2.append(model.predict(X_test)[0])
    y_true.append(y_test.values[0])

# Calculate metrics
accuracy = accuracy_score(y_true, y_pred2)
conf_matrix = confusion_matrix(y_true, y_pred2)
class_report = classification_report(y_true, y_pred2)


print("LOOCV Accuracy:", accuracy_score(y_true, y_pred2))
print("Classification Report:\n", classification_report(y_true, y_pred2))
# Out:
# LOOCV Accuracy: 0.6666666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.50      0.33      0.40         3
#
#     accuracy                           0.67         9
#    macro avg       0.61      0.58      0.58         9
# weighted avg       0.64      0.67      0.65         9

# %%
#KFold

# %%
from sklearn.model_selection import KFold

model = LogisticRegression(max_iter=1000)
kf = KFold(n_splits=3)  # Using 3 folds

y_pred3 = []
y_true1 = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_train, y_train)
    y_pred3.extend(model.predict(X_test))
    y_true1.extend(y_test)

# Calculate metrics
accuracy = accuracy_score(y_true1, y_pred3)
conf_matrix = confusion_matrix(y_true1, y_pred3)
class_report = classification_report(y_true1, y_pred3)

# Print metrics
print("K-Fold Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# K-Fold Accuracy: 0.5555555555555556
# Confusion Matrix:
#  [[3 3]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60         6
#            1       0.40      0.67      0.50         3
#
#     accuracy                           0.56         9
#    macro avg       0.57      0.58      0.55         9
# weighted avg       0.63      0.56      0.57         9

# %%
# Stratified split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd



# Stratified split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.3333333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.33         3
#    macro avg       0.25      0.25      0.25         3
# weighted avg       0.33      0.33      0.33         3
